# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %%
X,Y = make_blobs(
    n_samples=500,      # Total number of samples
    n_features=2,       # Two features
    centers=5,          # Number of clusters
    cluster_std=1.0,    # Standard deviation of each cluster
    random_state=42
)

# %%
plt.scatter(X[:,0],X[:,1])

# %%
# elbow method
wcss=[]
for i in range(1,11):
    km = KMeans(n_clusters=i)
    km.fit_predict(X)
    wcss.append(km.inertia_)
print(wcss)
plt.plot(range(1,11),wcss)
# Out:
# [30210.76504239943, 14726.117037953443, 3648.763582876105, 1543.3871978012933, 924.0989923406016, 844.8832833867508, 783.3710841191811, 704.7475273222371, 707.687027539411, 619.7385652115264]

# %%
km = KMeans(n_clusters=5)
y_pred = km.fit_predict(X)

plt.scatter(X[:,0],X[:,1],c=y_pred)

# %% [markdown]
# # 3-D clustering

# %%
# 3-d dataset
x,y= make_blobs(
    n_samples=500,      # Total number of samples
    n_features=3,       # Two features
    centers=4,          # Number of clusters
    cluster_std=1.0,    # Standard deviation of each cluster
    random_state=42
)
